# %%
#!  /bin/python3

from apyori import apriori
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv('datasets/store_data.csv')
print(dataset.shape)

# Transforming the list into a list of lists, so that each transaction can be indexed easier
transactions = []
for i in range(0, dataset.shape[0]):
    transactions.append([str(dataset.values[i, j])
                        for j in range(0, dataset.shape[1])])


# Please download this as a custom package --> type "apyori"
# To load custom packages, do not refresh the page. Instead, click on the reset button on the Console.

rules = apriori(transactions, min_support=0.005,
                min_confidence=0.25, min_lift=3, min_length=2)
# Support: number of transactions containing set of times / total number of transactions
# .      --> products that are bought at least 3 times a day --> 21 / 7501 = 0.0027
# Confidence: Should not be too high, as then this wil lead to obvious rules

# Try many combinations of values to experiment with the model

results = []
for item in rules:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")

    results.append(item)


# viewing the rules
print(len(results))

# Transferring the list to a table
results = pd.DataFrame(results)

results
# Out:
# (7500, 20)
# Rule: mushroom cream sauce -> escalope
# Support: 0.005733333333333333
# Confidence: 0.30069930069930073
# Lift: 3.7903273197390845
# =====================================
# Rule: pasta -> escalope
# Support: 0.005866666666666667
# Confidence: 0.37288135593220345
# Lift: 4.700185158809287
# =====================================
# Rule: ground beef -> herb & pepper
# Support: 0.016
# Confidence: 0.3234501347708895
# Lift: 3.2915549671393096
# =====================================
# Rule: ground beef -> tomato sauce
# Support: 0.005333333333333333
# Confidence: 0.37735849056603776
# Lift: 3.840147461662528
# =====================================
# Rule: olive oil -> whole wheat pasta
# Support: 0.008
# Confidence: 0.2714932126696833
# Lift: 4.130221288078346
# =====================================
# Rule: pasta -> shrimp
# Support: 0.005066666666666666
# Confidence: 0.3220338983050848
# Lift: 4.514493901473151
# =====================================
# Rule: frozen vegetables -> chocolate
# Support: 0.005333333333333333
# Confidence: 0.29629629629629634
# Lift: 3.1080031080031083
# =====================================
# Rule: nan -> mushroom cream sauce
# Support: 0.005733333333333333
# Confidence: 0.30069930069930073
# Lift: 3.7903273197390845
# =====================================
# Rule: pasta -> nan
# Support: 0.005866666666666667
# Confidence: 0.37288135593220345
# Lift: 4.700185158809287
# =====================================
# Rule: ground beef -> frozen vegetables
# Support: 0.008666666666666666
# Confidence: 0.3110047846889952
# Lift: 3.164906221394116
# =====================================
# Rule: shrimp -> frozen vegetables
# Support: 0.0072
# Confidence: 0.3068181818181818
# Lift: 3.2183725365543547
# =====================================
# Rule: tomatoes -> spaghetti
# Support: 0.006666666666666667
# Confidence: 0.3184713375796178
# Lift: 3.340608436149837
# =====================================
# Rule: grated cheese -> ground beef
# Support: 0.005333333333333333
# Confidence: 0.3225806451612903
# Lift: 3.282706701098612
# =====================================
# Rule: ground beef -> herb & pepper
# Support: 0.006666666666666667
# Confidence: 0.390625
# Lift: 3.975152645861601
# =====================================
# Rule: ground beef -> nan
# Support: 0.016
# Confidence: 0.3234501347708895
# Lift: 3.2915549671393096
# =====================================
# Rule: ground beef -> spaghetti
# Support: 0.0064
# Confidence: 0.3934426229508197
# Lift: 4.003825878061259
# =====================================
# Rule: ground beef -> nan
# Support: 0.005333333333333333
# Confidence: 0.37735849056603776
# Lift: 3.840147461662528
# =====================================
# Rule: ground beef -> spaghetti
# Support: 0.006
# Confidence: 0.5232558139534884
# Lift: 3.004914704939635
# =====================================
# Rule: olive oil -> nan
# Support: 0.008
# Confidence: 0.2714932126696833
# Lift: 4.130221288078346
# =====================================
# Rule: pasta -> nan
# Support: 0.005066666666666666
# Confidence: 0.3220338983050848
# Lift: 4.514493901473151
# =====================================
# Rule: nan -> frozen vegetables
# Support: 0.005333333333333333
# Confidence: 0.29629629629629634
# Lift: 3.1080031080031083
# =====================================
# Rule: ground beef -> nan
# Support: 0.008666666666666666
# Confidence: 0.3110047846889952
# Lift: 3.164906221394116
# =====================================
# Rule: shrimp -> nan
# Support: 0.0072
# Confidence: 0.3068181818181818
# Lift: 3.2183725365543547
# =====================================
# Rule: tomatoes -> spaghetti
# Support: 0.006666666666666667
# Confidence: 0.3184713375796178
# Lift: 3.340608436149837
# =====================================
# Rule: grated cheese -> ground beef
# Support: 0.005333333333333333
# Confidence: 0.3225806451612903
# Lift: 3.282706701098612
# =====================================
# Rule: ground beef -> nan
# Support: 0.006666666666666667
# Confidence: 0.390625
# Lift: 3.975152645861601
# =====================================
# Rule: ground beef -> nan
# Support: 0.0064
# Confidence: 0.3934426229508197
# Lift: 4.003825878061259
# =====================================
# Rule: ground beef -> nan
# Support: 0.006
# Confidence: 0.5232558139534884
# Lift: 3.004914704939635
# =====================================
# 28
#                                                items   support  \
# 0                   (mushroom cream sauce, escalope)  0.005733
# 1                                  (pasta, escalope)  0.005867
# 2                       (ground beef, herb & pepper)  0.016000
# 3                        (ground beef, tomato sauce)  0.005333
# 4                     (olive oil, whole wheat pasta)  0.008000
# 5                                    (pasta, shrimp)  0.005067
# 6             (frozen vegetables, chocolate, shrimp)  0.005333
# 7              (nan, mushroom cream sauce, escalope)  0.005733
# 8                             (pasta, nan, escalope)  0.005867
# 9        (ground beef, frozen vegetables, spaghetti)  0.008667
# 10        (shrimp, frozen vegetables, mineral water)  0.007200
# 11          (tomatoes, spaghetti, frozen vegetables)  0.006667
# 12           (grated cheese, ground beef, spaghetti)  0.005333
# 13       (ground beef, herb & pepper, mineral water)  0.006667
# 14                 (ground beef, nan, herb & pepper)  0.016000
# 15           (ground beef, spaghetti, herb & pepper)  0.006400
# 16                  (ground beef, nan, tomato sauce)  0.005333
# 17                  (ground beef, spaghetti, shrimp)  0.006000
# 18               (olive oil, nan, whole wheat pasta)  0.008000
# 19                              (pasta, nan, shrimp)  0.005067
# 20       (nan, frozen vegetables, chocolate, shrimp)  0.005333
# 21  (ground beef, nan, frozen vegetables, spaghetti)  0.008667
# 22   (shrimp, nan, frozen vegetables, mineral water)  0.007200
# 23     (tomatoes, spaghetti, nan, frozen vegetables)  0.006667
# 24      (grated cheese, ground beef, nan, spaghetti)  0.005333
# 25  (ground beef, nan, herb & pepper, mineral water)  0.006667
# 26      (ground beef, nan, spaghetti, herb & pepper)  0.006400
# 27             (ground beef, nan, spaghetti, shrimp)  0.006000
#
#                                    ordered_statistics
# 0   [((mushroom cream sauce), (escalope), 0.300699...
# 1   [((pasta), (escalope), 0.37288135593220345, 4....
# 2   [((herb & pepper), (ground beef), 0.3234501347...
# 3   [((tomato sauce), (ground beef), 0.37735849056...
# 4   [((whole wheat pasta), (olive oil), 0.27149321...
# 5   [((pasta), (shrimp), 0.3220338983050848, 4.514...
# 6   [((chocolate, shrimp), (frozen vegetables), 0....
# 7   [((mushroom cream sauce), (nan, escalope), 0.3...
# 8   [((pasta), (nan, escalope), 0.3728813559322034...
# 9   [((spaghetti, frozen vegetables), (ground beef...
# 10  [((shrimp, mineral water), (frozen vegetables)...
# 11  [((tomatoes, spaghetti), (frozen vegetables), ...
# 12  [((grated cheese, spaghetti), (ground beef), 0...
# 13  [((herb & pepper, mineral water), (ground beef...
# 14  [((herb & pepper), (ground beef, nan), 0.32345...
# 15  [((spaghetti, herb & pepper), (ground beef), 0...
# 16  [((tomato sauce), (ground beef, nan), 0.377358...
# 17  [((ground beef, shrimp), (spaghetti), 0.523255...
# 18  [((whole wheat pasta), (nan, olive oil), 0.271...
# 19  [((pasta), (nan, shrimp), 0.3220338983050848, ...
# 20  [((chocolate, shrimp), (nan, frozen vegetables...
# 21  [((spaghetti, frozen vegetables), (ground beef...
# 22  [((shrimp, mineral water), (nan, frozen vegeta...
# 23  [((tomatoes, spaghetti), (nan, frozen vegetabl...
# 24  [((grated cheese, spaghetti), (ground beef, na...
# 25  [((herb & pepper, mineral water), (ground beef...
# 26  [((spaghetti, herb & pepper), (ground beef, na...
# 27  [((ground beef, shrimp), (spaghetti, nan), 0.5...
